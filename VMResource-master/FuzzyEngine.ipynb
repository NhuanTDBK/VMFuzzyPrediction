# %%
from estimators.ACOEstimator import ACOEstimator
from estimators.NeuralFlow import NeuralFlowRegressor
from estimators.GAEstimator import GAEstimator
from estimators.OptimizerNNEstimator import OptimizerNNEstimator
from utils.GraphUtil import *
from utils.initializer import *
from estimators.FuzzyStep import *
from utils.SlidingWindowUtil import *
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
print 'FACO Model'
dat_usage = pd.read_csv('sample_610_10min.csv')['cpu_rate'][:2400]
# dat_usage = pd.read_csv('cpu_usage.csv')['cpu_usage']

# define training_set and testing _set
training_set_size = 1000
testing_set_size = 500


######## FUZZY before TRAINING
# length of sliding windows for input

#define training_set, testing set
X_train = np.zeros(training_set_size)
for i in range (0,training_set_size):
    X_train[i] = dat_usage[i]

y_train = np.zeros(training_set_size)
for i in range (0,training_set_size):
    y_train[i] = dat_usage[i + 1]

X_test = np.zeros(testing_set_size)
for i in range (0,testing_set_size):
    X_test[i] = dat_usage[i + training_set_size]

y_test = np.zeros(testing_set_size - 1)
for i in range (0,testing_set_size - 1):
    y_test[i] = dat_usage[i + training_set_size + 1]

# Number of hiddens node (one hidden layer)
n_hidden = 120

# Define neural shape
    # Input layer: [n_sample*n_size]
    # Hidden layer:
    # Output layer: regression
# neural_shape = [fuzzy_set_size,n_hidden,fuzzy_set_size]
# Out:
# FACO Model

# %%
# fuzzy before training
# fuzzy step:
# fuzzy_set = fuzzy(X_train)[1]
sliding_number = 1
X_train_f = np.array(fuzzy(X_train))
y_train_f = np.array(fuzzy(y_train))[sliding_number-1:]
X_test_f = np.array(fuzzy(X_test))


X_train_f = np.array(list(SlidingWindow(X_train_f,sliding_number,concatenate=True)))
# y_train_f = np.array(fuzzy(y_train)[n_sliding_window-1:])
X_test_f = np.array(list(SlidingWindow(X_test_f,sliding_number,concatenate=True)))
# X_train_f, a = fuzzy(X_train,automf=True)
# y_train_f,b = fuzzy(y_train,automf=True)
# X_test_f,c = fuzzy(X_test,automf=True)
neural_shape = [len(X_train_f[0]),n_hidden,len(y_train_f[0])]
# Initialize neural network model for regression

# %%
# Initialize ACO Estimator
estimator = ACOEstimator(Q=0.7,epsilon=0.1,number_of_solutions=130)
# estimator = GAEstimator(cross_rate=0.65,mutation_rate=0.01)
fit_param = {'neural_shape':neural_shape}
neuralNet = NeuralFlowRegressor(learning_rate=1E-03,verbose=1)

# There are many techniques for combining GA with NN. One of this, the optimizer solution of GA will be weights initialized of NN
optimizer = OptimizerNNEstimator(estimator,neuralNet)
# optimizer = neuralNet
optimizer.fit(X_train_f,y_train_f,**fit_param)
# Out:
# Initialization
# Initilization
# Step #100, epoch #12, avg. train loss: 0.58347
# Step #200, epoch #25, avg. train loss: 0.02177
# Step #300, epoch #37, avg. train loss: 0.01927
# Step #400, epoch #50, avg. train loss: 0.01758
# Step #500, epoch #62, avg. train loss: 0.01661
# Step #600, epoch #75, avg. train loss: 0.01589
# Step #700, epoch #87, avg. train loss: 0.01477
# Step #800, epoch #100, avg. train loss: 0.01403
# Step #900, epoch #112, avg. train loss: 0.01329
# Step #1000, epoch #125, avg. train loss: 0.01254
# Step #1100, epoch #12, avg. train loss: 0.01309
# Step #1200, epoch #25, avg. train loss: 0.01252
# Step #1300, epoch #37, avg. train loss: 0.01209
# Step #1400, epoch #50, avg. train loss: 0.01190
# Step #1500, epoch #62, avg. train loss: 0.01172
# Step #1600, epoch #75, avg. train loss: 0.01154
# Step #1700, epoch #87, avg. train loss: 0.01148
# Step #1800, epoch #100, avg. train loss: 0.01145
# Step #1900, epoch #112, avg. train loss: 0.01148
# Step #2000, epoch #125, avg. train loss: 0.01138
# Step #2100, epoch #12, avg. train loss: 0.01056
# Step #2200, epoch #25, avg. train loss: 0.01049
# Step #2300, epoch #37, avg. train loss: 0.01043
# Step #2400, epoch #50, avg. train loss: 0.01049
# Step #2500, epoch #62, avg. train loss: 0.01047
# Step #2600, epoch #75, avg. train loss: 0.01040
# Step #2700, epoch #87, avg. train loss: 0.01040
# Step #2800, epoch #100, avg. train loss: 0.01033
# Step #2900, epoch #112, avg. train loss: 0.01039
# Step #3000, epoch #125, avg. train loss: 0.01034
# Step #3100, epoch #12, avg. train loss: 0.01100
# Step #3200, epoch #25, avg. train loss: 0.01079
# Step #3300, epoch #37, avg. train loss: 0.01079
# Step #3400, epoch #50, avg. train loss: 0.01081
# Step #3500, epoch #62, avg. train loss: 0.01074
# Step #3600, epoch #75, avg. train loss: 0.01070
# Step #3700, epoch #87, avg. train loss: 0.01086
# Step #3800, epoch #100, avg. train loss: 0.01069
# Step #3900, epoch #112, avg. train loss: 0.01065
# Step #4000, epoch #125, avg. train loss: 0.01069
# Step #4100, epoch #12, avg. train loss: 0.01062
# Step #4200, epoch #25, avg. train loss: 0.01058
# Step #4300, epoch #37, avg. train loss: 0.01059
# Step #4400, epoch #50, avg. train loss: 0.01058
# Step #4500, epoch #62, avg. train loss: 0.01055
# Step #4600, epoch #75, avg. train loss: 0.01048
# Step #4700, epoch #87, avg. train loss: 0.01056
# Step #4800, epoch #100, avg. train loss: 0.01045
# Step #4900, epoch #112, avg. train loss: 0.01046
# Step #5000, epoch #125, avg. train loss: 0.01045
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-e53ae31a190c> in <module>()
#       8 optimizer = OptimizerNNEstimator(estimator,neuralNet)
#       9 # optimizer = neuralNet
# ---> 10 optimizer.fit(X_train_f,y_train_f,**fit_param)
#
# /usr/lib/python2.7/dist-packages/IPython/core/displayhook.pyc in __call__(self, result)
#     245             self.start_displayhook()
#     246             self.write_output_prompt()
# --> 247             format_dict, md_dict = self.compute_format_data(result)
#     248             self.write_format_data(format_dict, md_dict)
#     249             self.update_user_ns(result)
#
# /usr/lib/python2.7/dist-packages/IPython/core/displayhook.pyc in compute_format_data(self, result)
#     155
#     156         """
# --> 157         return self.shell.display_formatter.format(result)
#     158
#     159     def write_format_data(self, format_dict, md_dict=None):
#
# /usr/lib/python2.7/dist-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     150             md = None
#     151             try:
# --> 152                 data = formatter(obj)
#     153             except:
#     154                 # FIXME: log the exception
#
# /usr/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     479                 type_pprinters=self.type_printers,
#     480                 deferred_pprinters=self.deferred_printers)
# --> 481             printer.pretty(obj)
#     482             printer.flush()
#     483             return stream.getvalue()
#
# /usr/lib/python2.7/dist-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     360                             if callable(meth):
#     361                                 return meth(obj, self, cycle)
# --> 362             return _default_pprint(obj, self, cycle)
#     363         finally:
#     364             self.end_group()
#
# /usr/lib/python2.7/dist-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     480     if getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     481         # A user-provided repr.
# --> 482         p.text(repr(obj))
#     483         return
#     484     p.begin_group(1, '<')
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
# ...
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     139         else:
#     140             # use repr of the rest
# --> 141             this_repr = '%s=%s' % (k, printer(v))
#     142         if len(this_repr) > 500:
#     143             this_repr = this_repr[:300] + '...' + this_repr[-100:]
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in __repr__(self)
#     275         class_name = self.__class__.__name__
#     276         return '%s(%s)' % (class_name, _pprint(self.get_params(deep=False),
# --> 277                                                offset=len(class_name),),)
#     278
#     279
#
# /usr/local/lib/python2.7/dist-packages/sklearn/base.pyc in _pprint(params, offset, printer)
#     126     """
#     127     # Do a multi-line justified repr:
# --> 128     options = np.get_printoptions()
#     129     np.set_printoptions(precision=5, threshold=64, edgeitems=2)
#     130     params_list = list()
#
# RuntimeError: maximum recursion depth exceeded

# %%
print  optimizer.score(X_train_f,y_train_f)
y_pred = optimizer.predict(X_test_f)
# #defuzzy step:
ft = abs(defuzzy(X_test[sliding_number-1:],y_pred))
#mean_squared_error
print mean_squared_error(y_test[sliding_number-1:], ft)
#plot graph
plot_figure(ft,y_test,color=['blue','red'],title='FACONN')
# Out:
# 0.0106103861913
# ok
# 0.000737602745172
# Using matplotlib backend: Qt4Agg
